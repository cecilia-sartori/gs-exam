# %% [markdown]
# ## How to visualise data on a map if there is no latitude and longitude provided?
#
#
# Let's use the data from the [WHO Global Health Observatory](https://www.who.int/data/gho/indicator-metadata-registry/imr-details/3685) to figure out what countries have the highest prevalence rates of intimate partner violence among women aged 15-49. Consider two indicators:
#
# - Intimate partner violence prevalence among ever partnered women in their lifetime (%)
# - Intimate partner violence prevalence among ever partnered women in the previous 12 months (%) (latest available year: 2018)
#
#
# In most cases, the only way is to use a geocoder. It takes strings as input, such as addresses, and returns georeferenced locations. However,there is no free lunch. The names of the places can correspond to more than one location, such as Georgia (USA Federal State and country located in the Caucasus), and territories with controversial international recognition (Kosovo under UNSCR 1244, Palestinian territories, Hong Kong...) are hardly ever decoded correctly. What to do then? In general, providing more information to the geocoder ensures a better result. In the Georgia case, adding subregions to the query works.
#
# In some lucky cases (as the one following), when the data have no geometry but the country codes ([ISO](https://en.wikipedia.org/wiki/List_of_ISO_3166_country_codes)), we can use `plotly`, a fancy library that creates great interactive maps.
#
#
# Let's begin by importing the required modules:
#
# * Pandas for handling tabular data
# * Plotly for plotting interactive maps based on ISO codes

# %%
# Import required modules
import pandas as pd
import plotly.express as px
import plotly.graph_objects as go

# %%
# Read data
df12M = pd.read_csv("https://raw.githubusercontent.com/cecilia-sartori/gs-exam/main/notebooks/data/WHO_vaw_previous12months.csv")
dfLFT = pd.read_csv('https://raw.githubusercontent.com/cecilia-sartori/gs-exam/main/notebooks/data/WHO_vaw_lifetime.csv')

# %%
# Merge the two indicators
df = pd.merge(df12M, dfLFT, on= 'SpatialDimValueCode', how='outer',suffixes=('_last12M','_lifetime'))
df.head(3)
# Out:
#   IndicatorCode_last12M                                  Indicator_last12M  \
# 0             SDGIPV12M  Proportion of ever-partnered women and girls a...
# 1             SDGIPV12M  Proportion of ever-partnered women and girls a...
# 2             SDGIPV12M  Proportion of ever-partnered women and girls a...
#
#   ValueType_last12M ParentLocationCode_last12M ParentLocation_last12M  \
# 0           numeric                        AMR               Americas
# 1           numeric                        AMR               Americas
# 2           numeric                        WPR        Western Pacific
#
#   Location type_last12M SpatialDimValueCode    Location_last12M  \
# 0               Country                 DOM  Dominican Republic
# 1               Country                 MEX              Mexico
# 2               Country                 VNM            Viet Nam
#
#   Period type_last12M  Period_last12M  ... FactValueUoM_lifetime  \
# 0                Year          2018.0  ...                   NaN
# 1                Year          2018.0  ...                   NaN
# 2                Year          2018.0  ...                   NaN
#
#    FactValueNumericLowPrefix_lifetime  FactValueNumericLow_lifetime  \
# 0                                 NaN                          29.0
# 1                                 NaN                          35.0
# 2                                 NaN                          38.0
#
#    FactValueNumericHighPrefix_lifetime  FactValueNumericHigh_lifetime  \
# 0                                  NaN                           13.0
# 1                                  NaN                           16.0
# 2                                  NaN                           15.0
#
#    Value_lifetime  FactValueTranslationID_lifetime  FactComments_lifetime  \
# 0    19 [29 – 13]                              NaN                    NaN
# 1    24 [35 – 16]                              NaN                    NaN
# 2    25 [38 – 15]                              NaN                    NaN
#
#    Language_lifetime     DateModified_lifetime
# 0                 EN  2021-05-05T21:00:00.000Z
# 1                 EN  2021-05-05T21:00:00.000Z
# 2                 EN  2021-05-05T21:00:00.000Z
#
# [3 rows x 67 columns]

# %% [markdown]
# Create the Choropleth Map:

# %%
fig = px.choropleth(df, locations= 'SpatialDimValueCode', color = 'FactValueNumeric_lifetime',
                    hover_name='Location_lifetime',
                    hover_data={'FactValueNumeric_lifetime' : True ,
                                'FactValueNumeric_last12M' : True,
                                'SpatialDimValueCode' : False
                               },
                    labels={'FactValueNumeric_lifetime':'Lifetime (%)',
                            'FactValueNumeric_last12M' : 'Past Year (%)'
                           }
                    )

fig.update_layout(
    title = go.layout.Title(
        text = 'Women subjected to violence by an intimate partner <br> at least once in their lifetime (%)'),
        title_x=0.5,
        
    hoverlabel=dict(
        bgcolor="white",
        font_size=14,
        font_family="Rockwell"
    ),
    
    geo = go.layout.Geo(
        showframe = True,
        showcountries=True, countrycolor = "white",
        showocean = True, oceancolor = '#c9d2e0',
        coastlinecolor = "white",
        projection_type = 'natural earth'),

)

config = dict({'displayModeBar': False})
fig.show(config=config)

#fig.write_html("output/VAW_in_World.html",config=config)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="e7ae3266-db43-4ba1-999b-75e56946d46d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e7ae3266-db43-4ba1-999b-75e56946d46d")) {                    Plotly.newPlot(                        "e7ae3266-db43-4ba1-999b-75e56946d46d",                        [{"coloraxis":"coloraxis","customdata":[[19.0,10.0,"DOM"],[24.0,10.0,"MEX"],[25.0,10.0,"VNM"],[24.0,10.0,"GHA"],[25.0,10.0,"GMB"],[null,10.0,"MAR"],[25.0,10.0,"TUN"],[31.0,10.0,"GUY"],[38.0,11.0,"PER"],[19.0,11.0,"CPV"],[19.0,11.0,"MMR"],[27.0,11.0,"NPL"],[19.0,11.0,"BFA"],[23.0,12.0,"HTI"],[32.0,12.0,"TUR"],[27.0,12.0,"MNG"],[30.0,12.0,"COL"],[24.0,12.0,"SEN"],[24.0,13.0,"JOR"],[24.0,13.0,"NGA"],[null,13.0,"NER"],[25.0,13.0,"TGO"],[24.0,13.0,"ZAF"],[23.0,13.0,"KGZ"],[24.0,14.0,"TJK"],[33.0,14.0,"COK"],[31.0,14.0,"PLW"],[30.0,15.0,"EGY"],[26.0,15.0,"BEN"],[30.0,16.0,"MOZ"],[27.0,16.0,"NAM"],[29.0,16.0,"PAK"],[29.0,16.0,"TCD"],[27.0,16.0,"CIV"],[40.0,16.0,"LSO"],[30.0,17.0,"MWI"],[34.0,17.0,"BWA"],[null,17.0,"SDN"],[37.0,17.0,"TON"],[29.0,18.0,"MLI"],[35.0,18.0,"ZWE"],[42.0,18.0,"BOL"],[35.0,18.0,"IND"],[null,18.0,"SWZ"],[27.0,18.0,"STP"],[40.0,18.0,"WSM"],[31.0,18.0,"IRN"],[38.0,19.0,"MHL"],[12.0,2.0,"CHE"],[11.0,2.0,"SGP"],[36.0,20.0,"SLE"],[43.0,20.0,"NRU"],[39.0,20.0,"TUV"],[37.0,21.0,"GIN"],[29.0,21.0,"CAF"],[35.0,21.0,"FSM"],[39.0,22.0,"CMR"],[40.0,22.0,"BDI"],[41.0,22.0,"GAB"],[38.0,23.0,"KEN"],[38.0,23.0,"RWA"],[50.0,23.0,"BGD"],[52.0,23.0,"FJI"],[38.0,24.0,"TZA"],[38.0,25.0,"AGO"],[53.0,25.0,"KIR"],[45.0,26.0,"UGA"],[37.0,27.0,"ETH"],[43.0,27.0,"LBR"],[41.0,27.0,"SSD"],[41.0,28.0,"ZMB"],[38.0,28.0,"TLS"],[50.0,28.0,"SLB"],[46.0,29.0,"GNQ"],[47.0,29.0,"VUT"],[null,3.0,"CAN"],[21.0,3.0,"ISL"],[23.0,3.0,"AUS"],[23.0,3.0,"DNK"],[15.0,3.0,"ESP"],[16.0,3.0,"CYP"],[10.0,3.0,"GEO"],[12.0,3.0,"BIH"],[16.0,3.0,"IRL"],[13.0,3.0,"POL"],[18.0,3.0,"SVN"],[51.0,31.0,"PNG"],[46.0,35.0,"AFG"],[47.0,36.0,"COD"],[20.0,4.0,"JPN"],[23.0,4.0,"NZL"],[16.0,4.0,"ITA"],[15.0,4.0,"AUT"],[22.0,4.0,"CZE"],[20.0,4.0,"LUX"],[17.0,4.0,"SRB"],[13.0,4.0,"HRV"],[17.0,4.0,"MLT"],[16.0,4.0,"MNE"],[13.0,4.0,"MKD"],[24.0,4.0,"GBR"],[21.0,4.0,"EST"],[20.0,4.0,"NOR"],[18.0,4.0,"PRT"],[24.0,4.0,"LKA"],[18.0,4.0,"URY"],[22.0,5.0,"FRA"],[18.0,5.0,"GRC"],[21.0,5.0,"NLD"],[22.0,5.0,"LTU"],[27.0,5.0,"ARG"],[21.0,5.0,"DEU"],[10.0,5.0,"ARM"],[14.0,5.0,"CUB"],[14.0,5.0,"AZE"],[22.0,5.0,"BEL"],[21.0,6.0,"CHL"],[null,6.0,"ISR"],[18.0,6.0,"PRY"],[23.0,6.0,"BRA"],[19.0,6.0,"HUN"],[16.0,6.0,"KAZ"],[21.0,6.0,"SWE"],[19.0,6.0,"MDV"],[23.0,6.0,"NIC"],[21.0,6.0,"BLR"],[19.0,6.0,"BGR"],[25.0,6.0,"LVA"],[18.0,6.0,"SVK"],[13.0,6.0,"ALB"],[21.0,6.0,"SLV"],[14.0,6.0,"PHL"],[26.0,6.0,"USA"],[21.0,7.0,"GTM"],[17.0,7.0,"HND"],[24.0,7.0,"JAM"],[18.0,7.0,"ROU"],[27.0,7.0,"CRI"],[28.0,7.0,"TTO"],[23.0,8.0,"FIN"],[16.0,8.0,"PAN"],[28.0,8.0,"SUR"],[33.0,8.0,"ECU"],[null,8.0,"KOR"],[28.0,8.0,"GRD"],[19.0,8.0,"LAO"],[16.0,8.0,"COM"],[19.0,8.0,"VEN"],[24.0,8.0,"BLZ"],[19.0,8.0,"CHN"],[18.0,9.0,"UKR"],[22.0,9.0,"BTN"],[19.0,9.0,"KHM"],[27.0,9.0,"MDA"],[22.0,9.0,"IDN"],[24.0,9.0,"THA"],[19.0,null,"MYS"],[26.0,null,"IRQ"]],"geo":"geo","hovertemplate":"<b>%{hovertext}</b><br><br>Lifetime (%)=%{z}<br>Past Year (%)=%{customdata[1]}<extra></extra>","hovertext":["Dominican Republic","Mexico","Viet Nam","Ghana","Gambia",null,"Tunisia","Guyana","Peru","Cabo Verde","Myanmar","Nepal","Burkina Faso","Haiti","Turkey","Mongolia","Colombia","Senegal","Jordan","Nigeria",null,"Togo","South Africa","Kyrgyzstan","Tajikistan","Cook Islands","Palau","Egypt","Benin","Mozambique","Namibia","Pakistan","Chad","C\u00f4te d\u2019Ivoire","Lesotho","Malawi","Botswana",null,"Tonga","Mali","Zimbabwe","Bolivia (Plurinational State of)","India",null,"Sao Tome and Principe","Samoa","Iran (Is ...

# %% [markdown]
# States are correctly displayed and data easily turned into informative interactive conten.
